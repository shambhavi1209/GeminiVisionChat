# %%
# importing the libraries.
import google.generativeai as genai
import os
from dotenv import load_dotenv, find_dotenv

# loading the API key from .env and authenticating to Gemini.
load_dotenv(find_dotenv(), override=True)
os.environ.get('GOOGLE_API_KEY')

# configuring the API key.
genai.configure(api_key=os.environ.get('GOOGLE_API_KEY'))

# %%
from PIL import Image
image_path = input('Enter image path: ')

if not os.path.isfile(image_path):
    raise SystemExit('Invalid path! Existing ...')

img = Image.open(image_path)
img
# Out:
# Enter image path: oldtimercar.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x853>

# %%
import time
model = genai.GenerativeModel('gemini-1.5-flash')
while True:
    prompt = input('Ask something: ')
    if prompt.lower() not in ['exit', 'bye', 'quit']:
        response = model.generate_content([prompt, img])
        print('')
        print(response.text)
        print('-' * 100)
    else:
        print('Quitting ...')
        time.sleep(2)
        print('Bye-bye!')
        break
# Out:
# Ask something: is the car red|
#
# Yes, the car is red.
# ----------------------------------------------------------------------------------------------------
# Ask something: is there a man in the image
#
# No, there is not a man in the image.  The car is empty.
#
# ----------------------------------------------------------------------------------------------------
# Ask something: describe what you see
#
# The image shows a classic red convertible car parked on a dirt road. It is a sunny day with a partly cloudy sky. There are lush green trees on either side of the road. The car is facing towards the camera, with the hood open. The driver's side door is also open.  The road leads off into the distance, through a grove of trees. The car is a beautiful, classic example of American automobiles.
# ----------------------------------------------------------------------------------------------------
